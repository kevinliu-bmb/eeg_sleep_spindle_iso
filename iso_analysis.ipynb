# %%
import numpy as np
from scipy.signal import detrend
from sklearn.utils import resample
from scipy.stats import mode
from itertools import groupby
import mne
from mne.time_frequency import psd_array_multitaper
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
import os
import pandas as pd
from datetime import datetime
from scipy.integrate import simpson
import xml.etree.ElementTree as ET

# %%
def get_iso(edf, sleep_stages, artifact_indicator, ch_groups):
    """
    Computes the infraslow oscillation (ISO) spectrum from EEG data during Non-REM (NREM) sleep epochs.

    Parameters
    ----------
    edf : mne.io.Raw
        The EEG data object loaded using MNE, containing EEG signals and sampling frequency.
        
    sleep_stages : np.ndarray, shape (n_samples,)
        Numeric array indicating sleep stages at each EEG sample. Expected coding:
        0 = NREM, 1 = REM, 2 = Wake, 3 = Artifact.
        (Sleep stages will be resampled internally to match EEG data length.)
        
    artifact_indicator : np.ndarray, shape (n_samples,)
        Binary array (1-dimensional) indicating artifacts at each EEG sample (1 = artifact, 0 = clean).
        (Artifacts are resampled internally to match EEG data length.)

    ch_groups : list of list of str
        List defining channel groupings for analysis. Each inner list contains channel names to average.

    Returns
    -------
    spec_iso : np.ndarray, shape (n_channels, 3, n_freqs)
        ISO spectrum, separately computed for sigma_all, sigma_slow, and sigma_fast bands, for each channel group.

    freq_iso : np.ndarray, shape (n_freqs,)
        Frequency bins corresponding to ISO power spectra, typically in the infraslow range (0–0.1 Hz).
    """
    eeg = edf.get_data() * 1e6
    original_fs = edf.info['sfreq']
    fs = original_fs
 
    # Segment EEG into epochs
    window_size = int(round(4 * fs))
    step_size = int(round(2 * fs))
    epoch_time = 2
    start_ids = np.arange(0, eeg.shape[1] - window_size + 1, step_size)
    epochs = np.array([eeg[:, x:x + window_size] for x in start_ids])

    # Assign sleep stages and artifact indicators per epoch (identical logic to original function)
    sleep_stages = np.array([mode(sleep_stages[x:x + window_size], keepdims=False).mode for x in start_ids])
    artifact_indicator = np.array([artifact_indicator[x:x + window_size].any(axis=0) for x in start_ids])

    sleep_ids = np.where(sleep_stages == 0)[0]
    if len(sleep_ids) == 0:
        raise ValueError("No NREM epochs found.")
    start = sleep_ids[0]
    end = sleep_ids[-1] + 1
    epochs = epochs[start:end]
    sleep_stages = sleep_stages[start:end]
    artifact_indicator = artifact_indicator[start:end]

    # Detrend epochs
    epochs = detrend(epochs, axis=-1)

    # Calculate sigma-band power
    spec, freq = psd_array_multitaper(
        epochs, sfreq=fs, fmin=11, fmax=15, bandwidth=1,
        normalization='full', remove_dc=True, verbose=False
    )
    spec[np.isinf(spec)] = np.nan
    dfreq = freq[1] - freq[0]

    sigma_db = 10 * np.log10(np.sum(spec, axis=-1) * dfreq).T
    sigma_db[np.isinf(sigma_db)] = np.nan
    fs_sigma = 1 / epoch_time

    sigma_db = np.array([np.nanmean(sigma_db[[edf.ch_names.index(x) for x in xx]], axis=0) for xx in ch_groups])

    # Artifact_indicator is 1-dimensional; original assumed 2D channel-specific artifacts
    artifact_indicator2 = np.array([artifact_indicator for _ in ch_groups])

    window_size = int(round(256 * fs_sigma))
    step_size = int(round(64 * fs_sigma))
    freq_iso = np.linspace(0, 0.1, 101)[1:]
    spec_iso_all_ch = []

    for chi in range(len(ch_groups)):
        good_ids = (sleep_stages == 0) & (~artifact_indicator2[chi])
        spec_isos = []
        cc = 0
        for k, l in groupby(good_ids):
            ll = len(list(l))
            if not k:
                cc += ll
                continue
            for start in np.arange(cc, cc + ll - window_size + 1, step_size):
                xx = np.array([
                    sigma_db[chi, start:start + window_size],
                ])

                # Skip empty or all-NaN epochs explicitly
                if np.isnan(xx).all() or np.all(xx == 0):
                    continue

                xx = detrend(xx, axis=-1)
                spec_iso, freq_out = psd_array_multitaper(
                    xx, fs_sigma, fmin=0, fmax=0.2, bandwidth=0.01,
                    normalization='full', verbose=False
                )

                ff = interp1d(freq_out, spec_iso, axis=-1, bounds_error=False, fill_value='extrapolate')
                spec_iso = ff(freq_iso)

                spec_iso /= spec_iso.sum(axis=-1, keepdims=True)
                spec_isos.append(spec_iso)
            cc += ll

        # Explicit handling if no valid epochs found
        if len(spec_isos) == 0:
            print(f"No valid epochs for channel {ch_groups[chi]}. Returning NaN.")
            spec_iso_ch = np.full((1, len(freq_iso)), np.nan)
        else:
            spec_iso_ch = np.nanmean(np.array(spec_isos), axis=0)

        spec_iso_all_ch.append(spec_iso_ch)

    spec_iso = np.array(spec_iso_all_ch)
    return spec_iso, freq_iso


def plot_iso_single_subject_save(iso_df, subject_id, save_path):
    """
    Generate a single combined ISO plot for all channels and save the plot image.

    Parameters
    ----------
    iso_df : pd.DataFrame
        DataFrame containing ISO data for a single subject.

    subject_id : str
        Subject identifier used in the plot title.

    save_path : str
        Path (including filename) to save the generated plot.

    Returns
    -------
    None
    """
    freq = iso_df['frequency']
    channels = [col.split('_sigma')[0] for col in iso_df.columns if 'sigma_all' in col]

    plt.figure(figsize=(10, 6))

    # Plot each channel explicitly on the same plot
    for ch in channels:
        plt.plot(freq, iso_df[f'{ch}_sigma_all'], label=f'{ch}')

    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Relative Power')
    plt.title(f'Combined ISO Spectrum for Subject: {subject_id}')
    plt.legend(loc='best', fontsize='small', ncol=2)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    # Save explicitly
    plt.savefig(save_path, dpi=300)
    plt.close()

    print(f"Plot explicitly saved to: {save_path}")


def load_custom_montage(montage_path):
    """
    Load EEG channel montage from an XML file.

    Parameters
    ----------
    montage_path : str
        Path to the EEG montage XML file.

    Returns
    -------
    montage : mne.channels.DigMontage
        Custom montage object.
    """
    tree = ET.parse(montage_path)
    root = tree.getroot()
    namespace = {'ns': 'http://www.egi.com/coordinates_mff'}

    sensor_elements = root.findall('.//ns:sensor', namespaces=namespace)

    positions = []
    channel_names = []

    for sensor in sensor_elements:
        sensor_type = sensor.find('ns:type', namespaces=namespace).text
        if sensor_type == '0':
            number = int(sensor.find('ns:number', namespaces=namespace).text)
            x = float(sensor.find('ns:x', namespaces=namespace).text)
            y = float(sensor.find('ns:y', namespaces=namespace).text)
            z = float(sensor.find('ns:z', namespaces=namespace).text)

            positions.append([x, y, z])
            channel_names.append(f'EEG {number}')

    ch_pos = {name: pos for name, pos in zip(channel_names, positions)}
    montage = mne.channels.make_dig_montage(ch_pos=ch_pos, coord_frame='head')

    return montage


def plot_iso_topomap(edf_raw, spec_iso, freq_iso, subject_id, montage_path, save_path):
    """
    Generate and save topographical plots for ISO band power and peak frequency.

    Parameters
    ----------
    edf_raw : mne.io.Raw
        EEG data loaded using MNE.
    
    spec_iso : np.ndarray, shape (n_channels, 1, n_freqs)
        ISO spectrum computed by get_iso function.
    
    freq_iso : np.ndarray, shape (n_freqs,)
        ISO frequency bins.
    
    subject_id : str
        Identifier for the subject, used in plot titles and filenames.

    montage_path : str
        File path to the EEG channel montage (XML file).

    save_path : str
        File path to explicitly save the generated topomap figure.

    Returns
    -------
    None
    """
    # Load montage from XML
    tree = ET.parse(montage_path)
    root = tree.getroot()
    namespace = {'ns': 'http://www.egi.com/coordinates_mff'}

    sensor_elements = root.findall('.//ns:sensor', namespaces=namespace)

    positions = []
    channel_names = []

    for sensor in sensor_elements:
        sensor_type = sensor.find('ns:type', namespaces=namespace).text
        if sensor_type == '0':
            number = int(sensor.find('ns:number', namespaces=namespace).text)
            x = float(sensor.find('ns:x', namespaces=namespace).text)
            y = float(sensor.find('ns:y', namespaces=namespace).text)
            z = float(sensor.find('ns:z', namespaces=namespace).text)

            positions.append([x, y, z])
            channel_names.append(f'EEG {number}')

    ch_pos = {name: pos for name, pos in zip(channel_names, positions)}
    montage = mne.channels.make_dig_montage(ch_pos=ch_pos, coord_frame='head')

    edf_raw = edf_raw.copy().pick(picks=channel_names)
    edf_raw.set_montage(montage, on_missing='warn')

    # Compute ISO metrics
    iso_band = (freq_iso >= 0.005) & (freq_iso <= 0.03)
    iso_band_power = np.trapz(spec_iso[:, 0, iso_band], freq_iso[iso_band], axis=-1)
    iso_peak_freq = freq_iso[np.argmax(spec_iso[:, 0, :], axis=-1)]

    # Plotting without explicit scaling adjustments
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    mne.viz.plot_topomap(
        iso_band_power, edf_raw.info, axes=axes[0], cmap='viridis', show=False
    )
    axes[0].set_title('ISO Band Power (0.005–0.03 Hz)')

    mne.viz.plot_topomap(
        iso_peak_freq, edf_raw.info, axes=axes[1], cmap='plasma', show=False
    )
    axes[1].set_title('ISO Peak Frequency (Hz)')

    plt.suptitle(f'Subject: {subject_id}', fontsize=14)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

    # Explicitly save the figure
    plt.savefig(save_path, dpi=300)
    plt.close(fig)
    print(f"Topomap explicitly saved to: {save_path}")


def bootstrap_ci(data, ci=95, n_bootstrap=1000):
    bootstrapped_means = np.array([
        np.nanmean(resample(data, replace=True, n_samples=len(data)), axis=0)
        for _ in range(n_bootstrap)
    ])
    lower_bound = np.percentile(bootstrapped_means, (100 - ci) / 2, axis=0)
    upper_bound = np.percentile(bootstrapped_means, 100 - (100 - ci) / 2, axis=0)
    mean_spectrum = np.nanmean(data, axis=0)
    return mean_spectrum, lower_bound, upper_bound


def plot_group_iso_ci(
    iso_results_df, freq_iso, channel, group_col='group', ci=95, save_path=None
):
    """
    Generate and save ISO spectra plot with mean and CI for ASD and TD groups for a single channel.

    Parameters
    ----------
    iso_results_df : pd.DataFrame
        ISO results dataframe including subject and group data.
    freq_iso : np.ndarray
        ISO frequency bins.
    channel : str
        EEG channel name.
    group_col : str
        Column name indicating group labels.
    ci : int
        Confidence interval percentage.
    save_path : str or None
        File path to save the plot image.

    Returns
    -------
    None
    """
    channel_cols = [
        col for col in iso_results_df.columns if col.startswith(f'{channel}_sigma_all_')
    ]

    plt.figure(figsize=(10, 6))
    groups = iso_results_df[group_col].dropna().unique()

    for group in groups:
        group_data = iso_results_df[iso_results_df[group_col] == group][channel_cols].dropna()

        if group_data.empty or np.isnan(group_data.values).all():
            print(f"Warning: No valid data for group '{group}' in channel '{channel}'. Skipping.")
            continue

        mean_spectrum, lower_ci, upper_ci = bootstrap_ci(group_data.values, ci=ci)

        plt.plot(freq_iso, mean_spectrum, label=f'{group} Mean')
        plt.fill_between(freq_iso, lower_ci, upper_ci, alpha=0.3, label=f'{group} {ci}% CI')

    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Relative Power')
    plt.title(f'ISO Spectrum with {ci}% CI - {channel}')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300)
        print(f"Group plot saved explicitly to {save_path}")

    plt.close()


def load_eeg_data(base_path):
    """
    Load EEG data (EDF files), sleep stage labels, and artifact indicators from a structured directory.

    The function reads EEG recordings in EDF format along with their corresponding sleep stage and 
    artifact indicator files (stored as `.npz`) for two participant groups: Autism Spectrum Disorder (ASD)
    and Typically Developing (TD). Each group's data should reside within its own subfolder.

    Directory structure should follow this format explicitly:

    base_path/
    ├── edf/
    │   ├── ASD/
    │   └── TD/
    ├── sleep_stages/
    │   ├── ASD/
    │   └── TD/
    └── artifacts/
        ├── ASD/
        └── TD/

    Parameters
    ----------
    base_path : str
        Path to the root directory containing the 'edf', 'sleep_stages', and 'artifacts' subdirectories.

    Returns
    -------
    data : list of dict
        A list of dictionaries, each containing the following keys:
            - 'subject_id': str, subject identifier extracted from the EDF filename.
            - 'group': str, participant group ('ASD' or 'TD').
            - 'edf': mne.io.Raw, raw EEG data object loaded with MNE (not preloaded).
            - 'sleep_stages': np.ndarray, sleep stage labels loaded from the corresponding `.npz` file.
            - 'artifact_indicator': np.ndarray, binary artifact indicators loaded from the corresponding `.npz` file.
    """
    groups = ['ASD', 'TD']
    data = []

    for group in groups:
        edf_path = os.path.join(base_path, 'edf', group)
        stages_path = os.path.join(base_path, 'sleep_stages', group)
        artifact_path = os.path.join(base_path, 'artifacts', group)

        edf_files = sorted([f for f in os.listdir(edf_path) if f.lower().endswith('.edf')])

        for edf_file in edf_files:
            subject_id = os.path.splitext(edf_file)[0]

            stages_file = os.path.join(stages_path, f'sleep_stages_{subject_id}.npz')
            artifact_file = os.path.join(artifact_path, f'artifacts_{subject_id}.npz')
            edf_file_full = os.path.join(edf_path, edf_file)

            if not os.path.exists(stages_file):
                print(f"Missing sleep stage file for {subject_id}, skipping...")
                continue
            if not os.path.exists(artifact_file):
                print(f"Missing artifact file for {subject_id}, skipping...")
                continue

            edf_raw = mne.io.read_raw_edf(edf_file_full, preload=False, verbose=False)

            # Load the first available array from npz files automatically
            with np.load(stages_file) as stages_npz:
                sleep_stages = stages_npz[stages_npz.files[0]]

            with np.load(artifact_file) as artifacts_npz:
                artifact_indicator = artifacts_npz[artifacts_npz.files[0]]

            data.append({
                'subject_id': subject_id,
                'group': group,
                'edf': edf_raw,
                'sleep_stages': sleep_stages,
                'artifact_indicator': artifact_indicator
            })

            print(f"Loaded subject {subject_id} from group {group}")

    return data

# %%
def run_iso_analysis(
    data_list,
    montage_paths={'32': 'eeg_ch_coords/coordinates32.xml', '64': 'eeg_ch_coords/coordinates64.xml'},
    output_base_path='./iso_analysis_outputs'
):
    """
    Full pipeline to run ISO analysis on all subjects, saving all plots and metrics explicitly.

    Parameters
    ----------
    data_list : list of dict
        EEG data loaded with load_eeg_data function.
        
    montage_paths : dict
        Dictionary with keys '32' and '64' pointing to corresponding montage XML files.

    output_base_path : str
        Directory path to save results explicitly.

    Returns
    -------
    iso_results_df : pd.DataFrame
        ISO spectral results DataFrame.

    additional_metrics_df : pd.DataFrame
        ISO band power and peak frequency DataFrame.
    """
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_folder = os.path.join(output_base_path, f'iso_results_{timestamp}')
    os.makedirs(output_folder, exist_ok=True)
    print(f"Results explicitly saved to: {output_folder}")

    iso_results = []
    additional_metrics = []
    freq_iso = None

    for idx, subject in enumerate(data_list):
        subject_id = subject['subject_id']
        group = subject['group']
        print(f"\n[{idx+1}/{len(data_list)}] Processing subject: {subject_id} ({group})")

        try:
            edf_raw = subject['edf'].copy().load_data()
            sleep_stages = subject['sleep_stages']
            artifact_indicator = subject['artifact_indicator']

            # Choose correct montage explicitly
            n_channels = len(edf_raw.ch_names) - ('EEG VREF' in edf_raw.ch_names)
            montage_key = '64' if n_channels > 32 else '32'
            montage_path = montage_paths[montage_key]

            montage = load_custom_montage(montage_path)
            edf_raw.pick(picks=[ch for ch in edf_raw.ch_names if ch != 'EEG VREF'])
            edf_raw.set_montage(montage, on_missing='warn')

            ch_groups = [[ch] for ch in edf_raw.ch_names]

            # Run ISO analysis explicitly
            spec_iso, freq_iso = get_iso(edf_raw, sleep_stages, artifact_indicator, ch_groups)

            # Save ISO spectrum data explicitly
            iso_dict = {'subject_id': subject_id, 'group': group}
            for ch_idx, ch_name in enumerate(edf_raw.ch_names):
                for f_idx, freq in enumerate(freq_iso):
                    col_label = f'{ch_name}_sigma_all_{freq:.4f}Hz'
                    iso_dict[col_label] = spec_iso[ch_idx, 0, f_idx]
            iso_results.append(iso_dict)

            # ISO spectrum plot explicitly saved
            iso_df_single_subject = pd.DataFrame({'frequency': freq_iso})
            for ch_idx, ch_name in enumerate(edf_raw.ch_names):
                iso_df_single_subject[f'{ch_name}_sigma_all'] = spec_iso[ch_idx, 0, :]

            spectrum_plot_path = os.path.join(output_folder, f'{subject_id}_iso_spectrum.png')
            plot_iso_single_subject_save(iso_df_single_subject, subject_id, spectrum_plot_path)

            # ISO topomap explicitly saved
            topomap_plot_path = os.path.join(output_folder, f'{subject_id}_iso_topomaps.png')
            plot_iso_topomap(
                edf_raw, spec_iso, freq_iso, subject_id, montage_path, topomap_plot_path
            )

            # Additional metrics explicitly computed and saved
            band_power_dict = {'subject_id': subject_id, 'group': group}
            peak_freq_dict = {'subject_id': subject_id, 'group': group}
            iso_band = (freq_iso >= 0.005) & (freq_iso <= 0.03)

            for ch_idx, ch_name in enumerate(edf_raw.ch_names):
                iso_power = spec_iso[ch_idx, 0, :]
                auc_band_power = np.trapz(iso_power[iso_band], freq_iso[iso_band])
                peak_freq = freq_iso[np.argmax(iso_power)]

                band_power_dict[f'{ch_name}_ISO_bandpower_0.005-0.03Hz'] = auc_band_power
                peak_freq_dict[f'{ch_name}_ISO_peak_frequency'] = peak_freq

            additional_metrics.append({**band_power_dict, **peak_freq_dict})

        except Exception as e:
            print(f"Error processing subject {subject_id}: {e}")

    # Save ISO results explicitly
    iso_results_df = pd.DataFrame(iso_results)
    iso_results_csv = os.path.join(output_folder, 'iso_analysis_all_subjects.csv')
    iso_results_df.to_csv(iso_results_csv, index=False)
    print(f"\nISO spectra explicitly saved: {iso_results_csv}")

    # Save additional metrics explicitly
    additional_metrics_df = pd.DataFrame(additional_metrics)
    metrics_csv = os.path.join(output_folder, 'iso_additional_metrics.csv')
    additional_metrics_df.to_csv(metrics_csv, index=False)
    print(f"Additional ISO metrics explicitly saved: {metrics_csv}")

    # Generate group-wise ISO plots explicitly
    group_plot_dir = os.path.join(output_folder, 'group_plots')
    os.makedirs(group_plot_dir, exist_ok=True)

    for channel in edf_raw.ch_names:
        group_plot_path = os.path.join(group_plot_dir, f'ISO_CI_{channel}.png')
        plot_group_iso_ci(iso_results_df, freq_iso, channel, save_path=group_plot_path)

    return iso_results_df, additional_metrics_df

# %%
# Load all data
base_path = '/Users/kevinliu/git/mgh_eeg_spindle/data'
data_list = load_eeg_data(base_path)

# Quick check of first loaded subject
first_subject = data_list[0]

print("Subject ID:", first_subject['subject_id'])
print("Group:", first_subject['group'])
print("Sleep stages shape:", first_subject['sleep_stages'].shape)
print("Artifacts shape:", first_subject['artifact_indicator'].shape)
print("EDF info:", first_subject['edf'].info)
# Out:
# Loaded subject 10918067_20220415_142547_fil from group ASD
# Loaded subject 10994324_20220805_082743_fil from group ASD
# Loaded subject 11113647_20220818_142928_fil from group ASD
# Loaded subject 11196000_20220412_142232_fil from group ASD
# Loaded subject 11200338-1_20221102_144056_fil from group ASD
# Loaded subject 11212718-1_20221101_150706_fil from group ASD
# Loaded subject 11336460_20220725_100434_fil from group ASD
# Loaded subject 11353940-1_20221017_151814_fil from group ASD
# Loaded subject 11367187_20220621_143328_fil from group ASD
# Loaded subject 11402947_20220330_143311_fil from group ASD
# Loaded subject 11460732_20220524_100527_fil from group ASD
# Loaded subject 11537456_20220614_101224_fil from group ASD
# Loaded subject 11550215_20220331_142205_fil from group ASD
# Loaded subject 11630678_20220629_102630_fil from group ASD
# Loaded subject 11806907_20220406_142529 2_fil from group ASD
# Loaded subject 12315596-2_20220210_105023_fil from group ASD
# Loaded subject 12361287_20220401_102433_fil from group ASD
# Loaded subject 12371966-1_20220407_100947_fil from group ASD
# Loaded subject 12383094_20220413_085258_fil from group ASD
# Loaded subject 12383628_20220420_104150_fil from group ASD
# Loaded subject 12426525_20220927_102207_fil from group ASD
# Loaded subject 12442967_20220521_142622_fil from group ASD
# Loaded subject 12453943_20220531_102216_fil from group ASD
# Loaded subject 12460549_20220608_150447_fil from group ASD
# Loaded subject 12463729_20220621_101602_fil from group ASD
# Loaded subject 12488300-2_20220622_104528_fil from group ASD
# Loaded subject 12504239_20220728_142541_fil from group ASD
# Loaded subject 12506092-20221025_143547_fil from group ASD
# Loaded subject 12516508_20220720_143200_fil from group ASD
# Loaded subject 12604782-1_20221027_145412_fil from group ASD
# Loaded subject 12618801_20221115_143116_fil from group ASD
# Loaded subject 12636446_20221130_105733_fil from group ASD
# Loaded subject 2714675_20220415_101206_fil from group ASD
# Loaded subject 4121067_20220416_103237_fil from group ASD
# Loaded subject 10670384_20220413_143904_fil from group TD
# Loaded subject 11053855_20210219_095755_fil from group TD
# Loaded subject 11238018_20211108_142155_fil from group TD
# Loaded subject 11337951_20211117_142432_fil from group TD
# Loaded subject 11351624_20220414_142723_fil from group TD
# Loaded subject 11505953_20211019_102052_fil from group TD
# Loaded subject 11549585_20200702_143515_fil from group TD
# Loaded subject 11594675_20200907_102338_fil from group TD
# Loaded subject 11625584_20210928_101947_fil from group TD
# Loaded subject 11639535_20220704_143013_fil from group TD
# Loaded subject 11706194_20211203_102103_fil from group TD
# Loaded subject 11750225_20210107_144142_fil from group TD
# Loaded subject 11764921_20210118_144109_fil from group TD
# Loaded subject 11854262_20220218_111546_fil from group TD
# Loaded subject 11957179_20220421_143205_fil from group TD
# Loaded subject 12027962_20220507_143053_fil from group TD
# Loaded subject 12135041_20211111_142516_fil from group TD
# Loaded subject 12182475_20211201_142127_fil from group TD
# Loaded subject 12317359_20220623_144950_fil from group TD
# Loaded subject 12532961_20220817_143158_fil from group TD
# Loaded subject 12543262_20220913_142921_fil from group TD
# Loaded subject 12553348_20220820_150840_fil from group TD
# Loaded subject 4177114_20210913_141525_fil from group TD
# Loaded subject 4231776_20210706_141717_fil from group TD
# Loaded subject 4231776_20210706_141717_fil_1 from group TD
# Loaded subject 4391235_20220921_142521_fil from group TD
# Loaded subject 4440045_20210106_103718_fil from group TD
# Loaded subject 4564236_20210207_141444_fil from group TD
# Loaded subject 4564561_20210906_142516_fil from group TD
# Loaded subject 4570178-1_20220218_143504_fil from group TD
# Loaded subject 4579184_20220912_144139_fil from group TD
# Subject ID: 10918067_20220415_142547_fil
# Group: ASD
# Sleep stages shape: (433750,)
# Artifacts shape: (433750,)
# EDF info: <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG 1, EEG 2, EEG 3, EEG 4, EEG 5, EEG 6, EEG 7, EEG 8, EEG 9, ...
#  chs: 33 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2022-04-15 14:25:47 UTC
#  nchan: 33
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: 10918067, sex: 1, last_name: X>
# >

# %%
# Run ISO analysis for all subjects
iso_results_df, additional_metrics_df = run_iso_analysis(
    data_list,
    montage_paths={
        '32': 'eeg_ch_coords/coordinates32.xml',
        '64': 'eeg_ch_coords/coordinates64.xml'
    },
    output_base_path='./iso_analysis_outputs'
)
# Out:
# Results explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315
#
# [1/65] Processing subject: 10918067_20220415_142547_fil (ASD)
# Reading 0 ... 433749  =      0.000 ...  1734.996 secs...
# No valid epochs for channel ['EEG 1']. Returning NaN.
# No valid epochs for channel ['EEG 2']. Returning NaN.
# No valid epochs for channel ['EEG 3']. Returning NaN.
# No valid epochs for channel ['EEG 4']. Returning NaN.
# No valid epochs for channel ['EEG 5']. Returning NaN.
# No valid epochs for channel ['EEG 6']. Returning NaN.
# No valid epochs for channel ['EEG 7']. Returning NaN.
# No valid epochs for channel ['EEG 8']. Returning NaN.
# No valid epochs for channel ['EEG 9']. Returning NaN.
# No valid epochs for channel ['EEG 10']. Returning NaN.
# No valid epochs for channel ['EEG 11']. Returning NaN.
# No valid epochs for channel ['EEG 12']. Returning NaN.
# No valid epochs for channel ['EEG 13']. Returning NaN.
# No valid epochs for channel ['EEG 14']. Returning NaN.
# No valid epochs for channel ['EEG 15']. Returning NaN.
# No valid epochs for channel ['EEG 16']. Returning NaN.
# No valid epochs for channel ['EEG 17']. Returning NaN.
# No valid epochs for channel ['EEG 18']. Returning NaN.
# No valid epochs for channel ['EEG 19']. Returning NaN.
# No valid epochs for channel ['EEG 20']. Returning NaN.
# No valid epochs for channel ['EEG 21']. Returning NaN.
# No valid epochs for channel ['EEG 22']. Returning NaN.
# No valid epochs for channel ['EEG 23']. Returning NaN.
# No valid epochs for channel ['EEG 24']. Returning NaN.
# No valid epochs for channel ['EEG 25']. Returning NaN.
# No valid epochs for channel ['EEG 26']. Returning NaN.
# No valid epochs for channel ['EEG 27']. Returning NaN.
# No valid epochs for channel ['EEG 28']. Returning NaN.
# No valid epochs for channel ['EEG 29']. Returning NaN.
# No valid epochs for channel ['EEG 30']. Returning NaN.
# No valid epochs for channel ['EEG 31']. Returning NaN.
# No valid epochs for channel ['EEG 32']. Returning NaN.
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/10918067_20220415_142547_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/10918067_20220415_142547_fil_iso_topomaps.png
#
# [2/65] Processing subject: 10994324_20220805_082743_fil (ASD)
# Reading 0 ... 1164499  =      0.000 ...  4657.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/10994324_20220805_082743_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/10994324_20220805_082743_fil_iso_topomaps.png
#
# [3/65] Processing subject: 11113647_20220818_142928_fil (ASD)
# Reading 0 ... 988999  =      0.000 ...  3955.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11113647_20220818_142928_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11113647_20220818_142928_fil_iso_topomaps.png
#
# [4/65] Processing subject: 11196000_20220412_142232_fil (ASD)
# Reading 0 ... 1477999  =      0.000 ...  5911.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11196000_20220412_142232_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11196000_20220412_142232_fil_iso_topomaps.png
#
# [5/65] Processing subject: 11200338-1_20221102_144056_fil (ASD)
# Reading 0 ... 940749  =      0.000 ...  3762.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11200338-1_20221102_144056_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11200338-1_20221102_144056_fil_iso_topomaps.png
#
# [6/65] Processing subject: 11212718-1_20221101_150706_fil (ASD)
# Reading 0 ... 949749  =      0.000 ...  3798.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11212718-1_20221101_150706_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11212718-1_20221101_150706_fil_iso_topomaps.png
#
# [7/65] Processing subject: 11336460_20220725_100434_fil (ASD)
# Reading 0 ... 919999  =      0.000 ...  3679.996 secs...
# No valid epochs for channel ['EEG 1']. Returning NaN.
# No valid epochs for channel ['EEG 2']. Returning NaN.
# No valid epochs for channel ['EEG 3']. Returning NaN.
# No valid epochs for channel ['EEG 4']. Returning NaN.
# No valid epochs for channel ['EEG 5']. Returning NaN.
# No valid epochs for channel ['EEG 6']. Returning NaN.
# No valid epochs for channel ['EEG 7']. Returning NaN.
# No valid epochs for channel ['EEG 8']. Returning NaN.
# No valid epochs for channel ['EEG 9']. Returning NaN.
# No valid epochs for channel ['EEG 10']. Returning NaN.
# No valid epochs for channel ['EEG 11']. Returning NaN.
# No valid epochs for channel ['EEG 12']. Returning NaN.
# No valid epochs for channel ['EEG 13']. Returning NaN.
# No valid epochs for channel ['EEG 14']. Returning NaN.
# No valid epochs for channel ['EEG 15']. Returning NaN.
# No valid epochs for channel ['EEG 16']. Returning NaN.
# No valid epochs for channel ['EEG 17']. Returning NaN.
# No valid epochs for channel ['EEG 18']. Returning NaN.
# No valid epochs for channel ['EEG 19']. Returning NaN.
# No valid epochs for channel ['EEG 20']. Returning NaN.
# No valid epochs for channel ['EEG 21']. Returning NaN.
# No valid epochs for channel ['EEG 22']. Returning NaN.
# No valid epochs for channel ['EEG 23']. Returning NaN.
# No valid epochs for channel ['EEG 24']. Returning NaN.
# No valid epochs for channel ['EEG 25']. Returning NaN.
# No valid epochs for channel ['EEG 26']. Returning NaN.
# No valid epochs for channel ['EEG 27']. Returning NaN.
# No valid epochs for channel ['EEG 28']. Returning NaN.
# No valid epochs for channel ['EEG 29']. Returning NaN.
# No valid epochs for channel ['EEG 30']. Returning NaN.
# No valid epochs for channel ['EEG 31']. Returning NaN.
# No valid epochs for channel ['EEG 32']. Returning NaN.
# No valid epochs for channel ['EEG 33']. Returning NaN.
# No valid epochs for channel ['EEG 34']. Returning NaN.
# No valid epochs for channel ['EEG 35']. Returning NaN.
# No valid epochs for channel ['EEG 36']. Returning NaN.
# No valid epochs for channel ['EEG 37']. Returning NaN.
# No valid epochs for channel ['EEG 38']. Returning NaN.
# No valid epochs for channel ['EEG 39']. Returning NaN.
# No valid epochs for channel ['EEG 40']. Returning NaN.
# No valid epochs for channel ['EEG 41']. Returning NaN.
# No valid epochs for channel ['EEG 42']. Returning NaN.
# No valid epochs for channel ['EEG 43']. Returning NaN.
# No valid epochs for channel ['EEG 44']. Returning NaN.
# No valid epochs for channel ['EEG 45']. Returning NaN.
# No valid epochs for channel ['EEG 46']. Returning NaN.
# No valid epochs for channel ['EEG 47']. Returning NaN.
# No valid epochs for channel ['EEG 48']. Returning NaN.
# No valid epochs for channel ['EEG 49']. Returning NaN.
# No valid epochs for channel ['EEG 50']. Returning NaN.
# No valid epochs for channel ['EEG 51']. Returning NaN.
# No valid epochs for channel ['EEG 52']. Returning NaN.
# No valid epochs for channel ['EEG 53']. Returning NaN.
# No valid epochs for channel ['EEG 54']. Returning NaN.
# No valid epochs for channel ['EEG 55']. Returning NaN.
# No valid epochs for channel ['EEG 56']. Returning NaN.
# No valid epochs for channel ['EEG 57']. Returning NaN.
# No valid epochs for channel ['EEG 58']. Returning NaN.
# No valid epochs for channel ['EEG 59']. Returning NaN.
# No valid epochs for channel ['EEG 60']. Returning NaN.
# No valid epochs for channel ['EEG 61']. Returning NaN.
# No valid epochs for channel ['EEG 62']. Returning NaN.
# No valid epochs for channel ['EEG 63']. Returning NaN.
# No valid epochs for channel ['EEG 64']. Returning NaN.
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11336460_20220725_100434_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11336460_20220725_100434_fil_iso_topomaps.png
#
# [8/65] Processing subject: 11353940-1_20221017_151814_fil (ASD)
# Reading 0 ... 935749  =      0.000 ...  3742.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11353940-1_20221017_151814_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11353940-1_20221017_151814_fil_iso_topomaps.png
#
# [9/65] Processing subject: 11367187_20220621_143328_fil (ASD)
# Reading 0 ... 989999  =      0.000 ...  3959.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11367187_20220621_143328_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11367187_20220621_143328_fil_iso_topomaps.png
#
# [10/65] Processing subject: 11402947_20220330_143311_fil (ASD)
# Reading 0 ... 955749  =      0.000 ...  3822.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11402947_20220330_143311_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11402947_20220330_143311_fil_iso_topomaps.png
#
# [11/65] Processing subject: 11460732_20220524_100527_fil (ASD)
# Reading 0 ... 1116999  =      0.000 ...  4467.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11460732_20220524_100527_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11460732_20220524_100527_fil_iso_topomaps.png
#
# [12/65] Processing subject: 11537456_20220614_101224_fil (ASD)
# Reading 0 ... 1161999  =      0.000 ...  4647.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11537456_20220614_101224_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11537456_20220614_101224_fil_iso_topomaps.png
#
# [13/65] Processing subject: 11550215_20220331_142205_fil (ASD)
# Reading 0 ... 1032499  =      0.000 ...  4129.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11550215_20220331_142205_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11550215_20220331_142205_fil_iso_topomaps.png
#
# [14/65] Processing subject: 11630678_20220629_102630_fil (ASD)
# Reading 0 ... 1009749  =      0.000 ...  4038.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11630678_20220629_102630_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11630678_20220629_102630_fil_iso_topomaps.png
#
# [15/65] Processing subject: 11806907_20220406_142529 2_fil (ASD)
# Reading 0 ... 921249  =      0.000 ...  3684.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11806907_20220406_142529 2_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11806907_20220406_142529 2_fil_iso_topomaps.png
#
# [16/65] Processing subject: 12315596-2_20220210_105023_fil (ASD)
# Reading 0 ... 817999  =      0.000 ...  3271.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12315596-2_20220210_105023_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12315596-2_20220210_105023_fil_iso_topomaps.png
#
# [17/65] Processing subject: 12361287_20220401_102433_fil (ASD)
# Reading 0 ... 1139499  =      0.000 ...  4557.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12361287_20220401_102433_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12361287_20220401_102433_fil_iso_topomaps.png
#
# [18/65] Processing subject: 12371966-1_20220407_100947_fil (ASD)
# Reading 0 ... 1022999  =      0.000 ...  4091.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12371966-1_20220407_100947_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12371966-1_20220407_100947_fil_iso_topomaps.png
#
# [19/65] Processing subject: 12383094_20220413_085258_fil (ASD)
# Reading 0 ... 1593499  =      0.000 ...  6373.996 secs...
# No valid epochs for channel ['EEG 1']. Returning NaN.
# No valid epochs for channel ['EEG 2']. Returning NaN.
# No valid epochs for channel ['EEG 3']. Returning NaN.
# No valid epochs for channel ['EEG 4']. Returning NaN.
# No valid epochs for channel ['EEG 5']. Returning NaN.
# No valid epochs for channel ['EEG 6']. Returning NaN.
# No valid epochs for channel ['EEG 7']. Returning NaN.
# No valid epochs for channel ['EEG 8']. Returning NaN.
# No valid epochs for channel ['EEG 9']. Returning NaN.
# No valid epochs for channel ['EEG 10']. Returning NaN.
# No valid epochs for channel ['EEG 11']. Returning NaN.
# No valid epochs for channel ['EEG 12']. Returning NaN.
# No valid epochs for channel ['EEG 13']. Returning NaN.
# No valid epochs for channel ['EEG 14']. Returning NaN.
# No valid epochs for channel ['EEG 15']. Returning NaN.
# No valid epochs for channel ['EEG 16']. Returning NaN.
# No valid epochs for channel ['EEG 17']. Returning NaN.
# No valid epochs for channel ['EEG 18']. Returning NaN.
# No valid epochs for channel ['EEG 19']. Returning NaN.
# No valid epochs for channel ['EEG 20']. Returning NaN.
# No valid epochs for channel ['EEG 21']. Returning NaN.
# No valid epochs for channel ['EEG 22']. Returning NaN.
# No valid epochs for channel ['EEG 23']. Returning NaN.
# No valid epochs for channel ['EEG 24']. Returning NaN.
# No valid epochs for channel ['EEG 25']. Returning NaN.
# No valid epochs for channel ['EEG 26']. Returning NaN.
# No valid epochs for channel ['EEG 27']. Returning NaN.
# No valid epochs for channel ['EEG 28']. Returning NaN.
# No valid epochs for channel ['EEG 29']. Returning NaN.
# No valid epochs for channel ['EEG 30']. Returning NaN.
# No valid epochs for channel ['EEG 31']. Returning NaN.
# No valid epochs for channel ['EEG 32']. Returning NaN.
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12383094_20220413_085258_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12383094_20220413_085258_fil_iso_topomaps.png
#
# [20/65] Processing subject: 12383628_20220420_104150_fil (ASD)
# Reading 0 ... 1226249  =      0.000 ...  4904.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12383628_20220420_104150_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12383628_20220420_104150_fil_iso_topomaps.png
#
# [21/65] Processing subject: 12426525_20220927_102207_fil (ASD)
# Reading 0 ... 1236749  =      0.000 ...  4946.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12426525_20220927_102207_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12426525_20220927_102207_fil_iso_topomaps.png
#
# [22/65] Processing subject: 12442967_20220521_142622_fil (ASD)
# Reading 0 ... 1100999  =      0.000 ...  4403.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12442967_20220521_142622_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12442967_20220521_142622_fil_iso_topomaps.png
#
# [23/65] Processing subject: 12453943_20220531_102216_fil (ASD)
# Reading 0 ... 1258249  =      0.000 ...  5032.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12453943_20220531_102216_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12453943_20220531_102216_fil_iso_topomaps.png
#
# [24/65] Processing subject: 12460549_20220608_150447_fil (ASD)
# Reading 0 ... 1140499  =      0.000 ...  4561.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12460549_20220608_150447_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12460549_20220608_150447_fil_iso_topomaps.png
#
# [25/65] Processing subject: 12463729_20220621_101602_fil (ASD)
# Reading 0 ... 1199749  =      0.000 ...  4798.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12463729_20220621_101602_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12463729_20220621_101602_fil_iso_topomaps.png
#
# [26/65] Processing subject: 12488300-2_20220622_104528_fil (ASD)
# Reading 0 ... 1007999  =      0.000 ...  4031.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12488300-2_20220622_104528_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12488300-2_20220622_104528_fil_iso_topomaps.png
#
# [27/65] Processing subject: 12504239_20220728_142541_fil (ASD)
# Reading 0 ... 1016249  =      0.000 ...  4064.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12504239_20220728_142541_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12504239_20220728_142541_fil_iso_topomaps.png
#
# [28/65] Processing subject: 12506092-20221025_143547_fil (ASD)
# Reading 0 ... 1168499  =      0.000 ...  4673.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12506092-20221025_143547_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12506092-20221025_143547_fil_iso_topomaps.png
#
# [29/65] Processing subject: 12516508_20220720_143200_fil (ASD)
# Reading 0 ... 1350499  =      0.000 ...  5401.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12516508_20220720_143200_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12516508_20220720_143200_fil_iso_topomaps.png
#
# [30/65] Processing subject: 12604782-1_20221027_145412_fil (ASD)
# Reading 0 ... 887499  =      0.000 ...  3549.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12604782-1_20221027_145412_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12604782-1_20221027_145412_fil_iso_topomaps.png
#
# [31/65] Processing subject: 12618801_20221115_143116_fil (ASD)
# Reading 0 ... 1021749  =      0.000 ...  4086.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12618801_20221115_143116_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12618801_20221115_143116_fil_iso_topomaps.png
#
# [32/65] Processing subject: 12636446_20221130_105733_fil (ASD)
# Reading 0 ... 1124749  =      0.000 ...  4498.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12636446_20221130_105733_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12636446_20221130_105733_fil_iso_topomaps.png
#
# [33/65] Processing subject: 2714675_20220415_101206_fil (ASD)
# Reading 0 ... 1283499  =      0.000 ...  5133.996 secs...
# No valid epochs for channel ['EEG 1']. Returning NaN.
# No valid epochs for channel ['EEG 2']. Returning NaN.
# No valid epochs for channel ['EEG 3']. Returning NaN.
# No valid epochs for channel ['EEG 4']. Returning NaN.
# No valid epochs for channel ['EEG 5']. Returning NaN.
# No valid epochs for channel ['EEG 6']. Returning NaN.
# No valid epochs for channel ['EEG 7']. Returning NaN.
# No valid epochs for channel ['EEG 8']. Returning NaN.
# No valid epochs for channel ['EEG 9']. Returning NaN.
# No valid epochs for channel ['EEG 10']. Returning NaN.
# No valid epochs for channel ['EEG 11']. Returning NaN.
# No valid epochs for channel ['EEG 12']. Returning NaN.
# No valid epochs for channel ['EEG 13']. Returning NaN.
# No valid epochs for channel ['EEG 14']. Returning NaN.
# No valid epochs for channel ['EEG 15']. Returning NaN.
# No valid epochs for channel ['EEG 16']. Returning NaN.
# No valid epochs for channel ['EEG 17']. Returning NaN.
# No valid epochs for channel ['EEG 18']. Returning NaN.
# No valid epochs for channel ['EEG 19']. Returning NaN.
# No valid epochs for channel ['EEG 20']. Returning NaN.
# No valid epochs for channel ['EEG 21']. Returning NaN.
# No valid epochs for channel ['EEG 22']. Returning NaN.
# No valid epochs for channel ['EEG 23']. Returning NaN.
# No valid epochs for channel ['EEG 24']. Returning NaN.
# No valid epochs for channel ['EEG 25']. Returning NaN.
# No valid epochs for channel ['EEG 26']. Returning NaN.
# No valid epochs for channel ['EEG 27']. Returning NaN.
# No valid epochs for channel ['EEG 28']. Returning NaN.
# No valid epochs for channel ['EEG 29']. Returning NaN.
# No valid epochs for channel ['EEG 30']. Returning NaN.
# No valid epochs for channel ['EEG 31']. Returning NaN.
# No valid epochs for channel ['EEG 32']. Returning NaN.
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/2714675_20220415_101206_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/2714675_20220415_101206_fil_iso_topomaps.png
#
# [34/65] Processing subject: 4121067_20220416_103237_fil (ASD)
# Reading 0 ... 1059999  =      0.000 ...  4239.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4121067_20220416_103237_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4121067_20220416_103237_fil_iso_topomaps.png
#
# [35/65] Processing subject: 10670384_20220413_143904_fil (TD)
# Reading 0 ... 1284749  =      0.000 ...  5138.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/10670384_20220413_143904_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/10670384_20220413_143904_fil_iso_topomaps.png
#
# [36/65] Processing subject: 11053855_20210219_095755_fil (TD)
# Reading 0 ... 1312249  =      0.000 ...  5248.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11053855_20210219_095755_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11053855_20210219_095755_fil_iso_topomaps.png
#
# [37/65] Processing subject: 11238018_20211108_142155_fil (TD)
# Reading 0 ... 1321999  =      0.000 ...  5287.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11238018_20211108_142155_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11238018_20211108_142155_fil_iso_topomaps.png
#
# [38/65] Processing subject: 11337951_20211117_142432_fil (TD)
# Reading 0 ... 976499  =      0.000 ...  3905.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11337951_20211117_142432_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11337951_20211117_142432_fil_iso_topomaps.png
#
# [39/65] Processing subject: 11351624_20220414_142723_fil (TD)
# Reading 0 ... 1055499  =      0.000 ...  4221.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11351624_20220414_142723_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11351624_20220414_142723_fil_iso_topomaps.png
#
# [40/65] Processing subject: 11505953_20211019_102052_fil (TD)
# Reading 0 ... 885749  =      0.000 ...  3542.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11505953_20211019_102052_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11505953_20211019_102052_fil_iso_topomaps.png
#
# [41/65] Processing subject: 11549585_20200702_143515_fil (TD)
# Reading 0 ... 1369749  =      0.000 ...  5478.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11549585_20200702_143515_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11549585_20200702_143515_fil_iso_topomaps.png
#
# [42/65] Processing subject: 11594675_20200907_102338_fil (TD)
# Reading 0 ... 1392499  =      0.000 ...  5569.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11594675_20200907_102338_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11594675_20200907_102338_fil_iso_topomaps.png
#
# [43/65] Processing subject: 11625584_20210928_101947_fil (TD)
# Reading 0 ... 1012249  =      0.000 ...  4048.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11625584_20210928_101947_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11625584_20210928_101947_fil_iso_topomaps.png
#
# [44/65] Processing subject: 11639535_20220704_143013_fil (TD)
# Reading 0 ... 1262999  =      0.000 ...  5051.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11639535_20220704_143013_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11639535_20220704_143013_fil_iso_topomaps.png
#
# [45/65] Processing subject: 11706194_20211203_102103_fil (TD)
# Reading 0 ... 600749  =      0.000 ...  2402.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11706194_20211203_102103_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11706194_20211203_102103_fil_iso_topomaps.png
#
# [46/65] Processing subject: 11750225_20210107_144142_fil (TD)
# Reading 0 ... 1079749  =      0.000 ...  4318.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11750225_20210107_144142_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11750225_20210107_144142_fil_iso_topomaps.png
#
# [47/65] Processing subject: 11764921_20210118_144109_fil (TD)
# Reading 0 ... 1377999  =      0.000 ...  5511.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11764921_20210118_144109_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11764921_20210118_144109_fil_iso_topomaps.png
#
# [48/65] Processing subject: 11854262_20220218_111546_fil (TD)
# Reading 0 ... 793749  =      0.000 ...  3174.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11854262_20220218_111546_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11854262_20220218_111546_fil_iso_topomaps.png
#
# [49/65] Processing subject: 11957179_20220421_143205_fil (TD)
# Reading 0 ... 1045749  =      0.000 ...  4182.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11957179_20220421_143205_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/11957179_20220421_143205_fil_iso_topomaps.png
#
# [50/65] Processing subject: 12027962_20220507_143053_fil (TD)
# Reading 0 ... 1437749  =      0.000 ...  5750.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12027962_20220507_143053_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12027962_20220507_143053_fil_iso_topomaps.png
#
# [51/65] Processing subject: 12135041_20211111_142516_fil (TD)
# Reading 0 ... 1244499  =      0.000 ...  4977.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12135041_20211111_142516_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12135041_20211111_142516_fil_iso_topomaps.png
#
# [52/65] Processing subject: 12182475_20211201_142127_fil (TD)
# Reading 0 ... 1116749  =      0.000 ...  4466.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12182475_20211201_142127_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12182475_20211201_142127_fil_iso_topomaps.png
#
# [53/65] Processing subject: 12317359_20220623_144950_fil (TD)
# Reading 0 ... 852249  =      0.000 ...  3408.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12317359_20220623_144950_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12317359_20220623_144950_fil_iso_topomaps.png
#
# [54/65] Processing subject: 12532961_20220817_143158_fil (TD)
# Reading 0 ... 1065249  =      0.000 ...  4260.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12532961_20220817_143158_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12532961_20220817_143158_fil_iso_topomaps.png
#
# [55/65] Processing subject: 12543262_20220913_142921_fil (TD)
# Reading 0 ... 1232249  =      0.000 ...  4928.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12543262_20220913_142921_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12543262_20220913_142921_fil_iso_topomaps.png
#
# [56/65] Processing subject: 12553348_20220820_150840_fil (TD)
# Reading 0 ... 1080499  =      0.000 ...  4321.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12553348_20220820_150840_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/12553348_20220820_150840_fil_iso_topomaps.png
#
# [57/65] Processing subject: 4177114_20210913_141525_fil (TD)
# Reading 0 ... 989749  =      0.000 ...  3958.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4177114_20210913_141525_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4177114_20210913_141525_fil_iso_topomaps.png
#
# [58/65] Processing subject: 4231776_20210706_141717_fil (TD)
# Reading 0 ... 1266999  =      0.000 ...  5067.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4231776_20210706_141717_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4231776_20210706_141717_fil_iso_topomaps.png
#
# [59/65] Processing subject: 4231776_20210706_141717_fil_1 (TD)
# Reading 0 ... 1266999  =      0.000 ...  5067.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4231776_20210706_141717_fil_1_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4231776_20210706_141717_fil_1_iso_topomaps.png
#
# [60/65] Processing subject: 4391235_20220921_142521_fil (TD)
# Reading 0 ... 878499  =      0.000 ...  3513.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4391235_20220921_142521_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4391235_20220921_142521_fil_iso_topomaps.png
#
# [61/65] Processing subject: 4440045_20210106_103718_fil (TD)
# Reading 0 ... 1173999  =      0.000 ...  4695.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4440045_20210106_103718_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4440045_20210106_103718_fil_iso_topomaps.png
#
# [62/65] Processing subject: 4564236_20210207_141444_fil (TD)
# Reading 0 ... 1361999  =      0.000 ...  5447.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4564236_20210207_141444_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4564236_20210207_141444_fil_iso_topomaps.png
#
# [63/65] Processing subject: 4564561_20210906_142516_fil (TD)
# Reading 0 ... 1051499  =      0.000 ...  4205.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4564561_20210906_142516_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4564561_20210906_142516_fil_iso_topomaps.png
#
# [64/65] Processing subject: 4570178-1_20220218_143504_fil (TD)
# Reading 0 ... 1060249  =      0.000 ...  4240.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4570178-1_20220218_143504_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4570178-1_20220218_143504_fil_iso_topomaps.png
#
# [65/65] Processing subject: 4579184_20220912_144139_fil (TD)
# Reading 0 ... 1378999  =      0.000 ...  5515.996 secs...
# Plot explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4579184_20220912_144139_fil_iso_spectrum.png
# Topomap explicitly saved to: ./iso_analysis_outputs/iso_results_20250401_184315/4579184_20220912_144139_fil_iso_topomaps.png
#
# ISO spectra explicitly saved: ./iso_analysis_outputs/iso_results_20250401_184315/iso_analysis_all_subjects.csv
# Additional ISO metrics explicitly saved: ./iso_analysis_outputs/iso_results_20250401_184315/iso_additional_metrics.csv
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 1.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 2.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 3.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 4.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 5.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 6.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 7.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 8.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 9.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 10.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 11.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 12.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 13.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 14.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 15.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 16.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 17.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 18.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 19.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 20.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 21.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 22.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 23.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 24.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 25.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 26.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 27.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 28.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 29.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 30.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 31.png
# Group plot saved explicitly to ./iso_analysis_outputs/iso_results_20250401_184315/group_plots/ISO_CI_EEG 32.png
